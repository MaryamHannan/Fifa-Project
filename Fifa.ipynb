# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fifa=pd.read_csv(r"C:\Users\moizr\Downloads\players_20.csv\players_20.csv")
fifa.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %%
fifa.shape
# Out:
# (18278, 104)

# %%
fifa.describe()
# Out:
#            sofifa_id           age     height_cm     weight_kg       overall  \
# count   18278.000000  18278.000000  18278.000000  18278.000000  18278.000000
# mean   219738.864482     25.283291    181.362184     75.276343     66.244994
# std     27960.200461      4.656964      6.756961      7.047744      6.949953
# min       768.000000     16.000000    156.000000     50.000000     48.000000
# 25%    204445.500000     22.000000    177.000000     70.000000     62.000000
# 50%    226165.000000     25.000000    181.000000     75.000000     66.000000
# 75%    240795.750000     29.000000    186.000000     80.000000     71.000000
# max    252905.000000     42.000000    205.000000    110.000000     94.000000
#
#           potential     value_eur       wage_eur  international_reputation  \
# count  18278.000000  1.827800e+04   18278.000000              18278.000000
# mean      71.546887  2.484038e+06    9456.942773                  1.103184
# ...

# %%
for col in fifa.columns:
    print(col)
# Out:
# sofifa_id
# player_url
# short_name
# long_name
# age
# dob
# height_cm
# weight_kg
# nationality
# club
# overall
# potential
# value_eur
# wage_eur
# player_positions
# preferred_foot
# international_reputation
# weak_foot
# skill_moves
# work_rate
# body_type
# real_face
# release_clause_eur
# player_tags
# team_position
# team_jersey_number
# loaned_from
# joined
# contract_valid_until
# nation_position
# nation_jersey_number
# pace
# shooting
# passing
# dribbling
# defending
# physic
# gk_diving
# gk_handling
# gk_kicking
# gk_reflexes
# gk_speed
# gk_positioning
# player_traits
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# power_strength
# power_long_shots
# ...

# %%
fifa['nationality'].value_counts()
# Out:
# nationality
# England                1667
# Germany                1216
# Spain                  1035
# France                  984
# Argentina               886
#                        ...
# Liberia                   1
# São Tomé & Príncipe       1
# Puerto Rico               1
# Bahrain                   1
# Indonesia                 1
# Name: count, Length: 162, dtype: int64

# %%
fifa['nationality'].value_counts()[:10]
# Out:
# nationality
# England        1667
# Germany        1216
# Spain          1035
# France          984
# Argentina       886
# Brazil          824
# Italy           732
# Colombia        591
# Japan           453
# Netherlands     416
# Name: count, dtype: int64

# %%
fifa['nationality'].value_counts()[:5].keys()
# Out:
# Index(['England', 'Germany', 'Spain', 'France', 'Argentina'], dtype='object', name='nationality')

# %%
fifa['nationality'].value_counts()[:5]
# Out:
# nationality
# England      1667
# Germany      1216
# Spain        1035
# France        984
# Argentina     886
# Name: count, dtype: int64

# %%
plt.figure(figsize=(5,5))
plt.bar(list(fifa['nationality'].value_counts()[:5].keys()),(list(fifa['nationality'].value_counts()[:5])))
plt.show()

# %%
playersal=fifa[['short_name','wage_eur']]
playersal.head(2)
# Out:
#           short_name  wage_eur
# 0           L. Messi    565000
# 1  Cristiano Ronaldo    405000

# %%
playersal = playersal.sort_values(by=['wage_eur'], ascending=False)
playersal
# Out:
#               short_name  wage_eur
# 0               L. Messi    565000
# 4              E. Hazard    470000
# 1      Cristiano Ronaldo    405000
# 5           K. De Bruyne    370000
# 22          A. Griezmann    370000
# ...                  ...       ...
# 565         J. Serendero         0
# 1868           M. Mevlja         0
# 14723       R. Fernández         0
# 16356          H. Ivanov         0
# 3053       F. Kudryashov         0
#
# [18278 rows x 2 columns]

# %%
plt.figure(figsize=(5, 5))
plt.bar(list(playersal['short_name'])[0:5], list(playersal['wage_eur'])[0:5])
plt.show()

# %%
fifa['nationality']=='Germany'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18273    False
# 18274    False
# 18275    False
# 18276    False
# 18277    False
# Name: nationality, Length: 18278, dtype: bool

# %%
Germany=fifa[fifa['nationality']=='Germany']
Germany.head()
# Out:
#     sofifa_id                                         player_url  \
# 6      192448  https://sofifa.com/player/192448/marc-andre-te...
# 31     167495  https://sofifa.com/player/167495/manuel-neuer/...
# 36     182521  https://sofifa.com/player/182521/toni-kroos/20...
# 37     188350  https://sofifa.com/player/188350/marco-reus/20...
# 49     178603  https://sofifa.com/player/178603/mats-hummels/...
#
#        short_name              long_name  age         dob  height_cm  \
# 6   M. ter Stegen  Marc-André ter Stegen   27  1992-04-30        187
# 31       M. Neuer           Manuel Neuer   33  1986-03-27        193
# 36       T. Kroos             Toni Kroos   29  1990-01-04        183
# 37        M. Reus             Marco Reus   30  1989-05-31        180
# 49     M. Hummels          Mats  Hummels   30  1988-12-16        191
#
#     weight_kg nationality               club  ...   lwb   ldm   cdm   rdm  \
# 6          85     Germany       FC Barcelona  ...   NaN   NaN   NaN   NaN
# ...

# %%
Germany.sort_values(by=['height_cm'],ascending=False).head(3)
# Out:
#       sofifa_id                                         player_url  \
# 8016     236831  https://sofifa.com/player/236831/aaron-seydel/...
# 1217     200212  https://sofifa.com/player/200212/michael-esser...
# 1389     199833  https://sofifa.com/player/199833/lars-unnersta...
#
#          short_name        long_name  age         dob  height_cm  weight_kg  \
# 8016      A. Seydel     Aaron Seydel   23  1996-02-07        199         90
# 1217       M. Esser    Michael Esser   31  1987-11-22        198         97
# 1389  L. Unnerstall  Lars Unnerstall   28  1990-07-20        198        103
#
#      nationality             club  ...   lwb   ldm   cdm   rdm   rwb    lb  \
# 8016     Germany  1. FSV Mainz 05  ...  46+2  43+2  43+2  43+2  46+2  44+2
# 1217     Germany      Hannover 96  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 1389     Germany              PSV  ...   NaN   NaN   NaN   NaN   NaN   NaN
#
#        lcb    cb   rcb    rb
# 8016  43+2  43+2  43+2  44+2
# ...

# %%
Germany.sort_values(by=['weight_kg'],ascending=False).head(3)
# Out:
#        sofifa_id                                         player_url  \
# 13576     239746  https://sofifa.com/player/239746/lukas-watkowi...
# 1389      199833  https://sofifa.com/player/199833/lars-unnersta...
# 518       179783  https://sofifa.com/player/179783/ralf-fahrmann...
#
#           short_name        long_name  age         dob  height_cm  weight_kg  \
# 13576   L. Watkowiak  Lukas Watkowiak   23  1996-03-06        197        103
# 1389   L. Unnerstall  Lars Unnerstall   28  1990-07-20        198        103
# 518      R. Fährmann    Ralf Fährmann   30  1988-09-27        197         98
#
#       nationality                club  ...  lwb  ldm  cdm  rdm  rwb   lb  lcb  \
# 13576     Germany  SV Wehen Wiesbaden  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1389      Germany                 PSV  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 518       Germany        Norwich City  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#         cb  rcb   rb
# 13576  NaN  NaN  NaN
# 1389   NaN  NaN  NaN
# ...

# %%
Germany.sort_values(by=['wage_eur'],ascending=False).head(3)
# Out:
#     sofifa_id                                         player_url  \
# 36     182521  https://sofifa.com/player/182521/toni-kroos/20...
# 6      192448  https://sofifa.com/player/192448/marc-andre-te...
# 55     222492  https://sofifa.com/player/222492/leroy-sane/20...
#
#        short_name              long_name  age         dob  height_cm  \
# 36       T. Kroos             Toni Kroos   29  1990-01-04        183
# 6   M. ter Stegen  Marc-André ter Stegen   27  1992-04-30        187
# 55        L. Sané             Leroy Sané   23  1996-01-11        183
#
#     weight_kg nationality             club  ...   lwb   ldm   cdm   rdm   rwb  \
# 36         76     Germany      Real Madrid  ...  75+3  79+3  79+3  79+3  75+3
# 6          85     Germany     FC Barcelona  ...   NaN   NaN   NaN   NaN   NaN
# 55         75     Germany  Manchester City  ...  65+2  59+2  59+2  59+2  65+2
#
#       lb   lcb    cb   rcb    rb
# 36  72+3  69+3  69+3  69+3  72+3
# 6    NaN   NaN   NaN   NaN   NaN
# ...

# %%
playershooting=fifa[['short_name','shooting']]
playershooting.head()
# Out:
#           short_name  shooting
# 0           L. Messi      92.0
# 1  Cristiano Ronaldo      93.0
# 2          Neymar Jr      85.0
# 3           J. Oblak       NaN
# 4          E. Hazard      83.0

# %%
playershooting_sorted = playershooting.sort_values(by='shooting', ascending=False).head()

# %%
playershooting_sorted
# Out:
#             short_name  shooting
# 1    Cristiano Ronaldo      93.0
# 0             L. Messi      92.0
# 12             H. Kane      91.0
# 17           S. Agüero      90.0
# 205    F. Quagliarella      89.0

# %%
playerdefending=fifa[['short_name','defending','nationality','club']]

# %%
playerdefending.head()
# Out:
#           short_name  defending nationality                 club
# 0           L. Messi       39.0   Argentina         FC Barcelona
# 1  Cristiano Ronaldo       35.0    Portugal             Juventus
# 2          Neymar Jr       32.0      Brazil  Paris Saint-Germain
# 3           J. Oblak        NaN    Slovenia      Atlético Madrid
# 4          E. Hazard       35.0     Belgium          Real Madrid

# %%
playerdefending.sort_values(by='defending',ascending=False).head()
# Out:
#       short_name  defending  nationality               club
# 16  G. Chiellini       90.0        Italy           Juventus
# 7    V. van Dijk       90.0  Netherlands          Liverpool
# 11  K. Koulibaly       89.0      Senegal             Napoli
# 35      D. Godín       89.0      Uruguay              Inter
# 49    M. Hummels       89.0      Germany  Borussia Dortmund

# %%
realmadrid=fifa[fifa['club']=='Real Madrid']
realmadrid.sort_values(by='wage_eur',ascending=False).head(3)
# Out:
#     sofifa_id                                         player_url short_name  \
# 4      183277  https://sofifa.com/player/183277/eden-hazard/2...  E. Hazard
# 8      177003  https://sofifa.com/player/177003/luka-modric/2...  L. Modrić
# 36     182521  https://sofifa.com/player/182521/toni-kroos/20...   T. Kroos
#
#       long_name  age         dob  height_cm  weight_kg nationality  \
# 4   Eden Hazard   28  1991-01-07        175         74     Belgium
# 8   Luka Modrić   33  1985-09-09        172         66     Croatia
# 36   Toni Kroos   29  1990-01-04        183         76     Germany
#
#            club  ...   lwb   ldm   cdm   rdm   rwb    lb   lcb    cb   rcb  \
# 4   Real Madrid  ...  66+3  63+3  63+3  63+3  66+3  61+3  49+3  49+3  49+3
# 8   Real Madrid  ...  81+3  81+3  81+3  81+3  81+3  79+3  72+3  72+3  72+3
# 36  Real Madrid  ...  75+3  79+3  79+3  79+3  75+3  72+3  69+3  69+3  69+3
#
#       rb
# 4   61+3
# 8   79+3
# 36  72+3
#
# [3 rows x 104 columns]

# %%
realmadrid.sort_values(by='defending',ascending=False).head(3)
# Out:
#     sofifa_id                                         player_url  \
# 18     155862  https://sofifa.com/player/155862/sergio-ramos-...
# 42     200145  https://sofifa.com/player/200145/carlos-henriq...
# 76     201535  https://sofifa.com/player/201535/raphael-varan...
#
#       short_name                          long_name  age         dob  \
# 18  Sergio Ramos                Sergio Ramos García   33  1986-03-30
# 42      Casemiro  Carlos Henrique Venancio Casimiro   27  1992-02-23
# 76     R. Varane                     Raphaël Varane   26  1993-04-25
#
#     height_cm  weight_kg nationality         club  ...   lwb   ldm   cdm  \
# 18        184         82       Spain  Real Madrid  ...  80+3  84+3  84+3
# 42        185         84      Brazil  Real Madrid  ...  78+3  84+3  84+3
# 76        191         81      France  Real Madrid  ...  74+3  79+3  79+3
#
#      rdm   rwb    lb   lcb    cb   rcb    rb
# 18  84+3  80+3  82+3  87+3  87+3  87+3  82+3
# ...

# %%
realmadrid.sort_values(by='shooting',ascending=False).head(3)
# Out:
#      sofifa_id                                         player_url  \
# 100     173731  https://sofifa.com/player/173731/gareth-bale/2...
# 106     198710  https://sofifa.com/player/198710/james-rodrigu...
# 4       183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#        short_name                    long_name  age         dob  height_cm  \
# 100       G. Bale            Gareth Frank Bale   29  1989-07-16        185
# 106  J. Rodríguez  James David Rodríguez Rubio   27  1991-07-12        180
# 4       E. Hazard                  Eden Hazard   28  1991-01-07        175
#
#      weight_kg nationality         club  ...   lwb   ldm   cdm   rdm   rwb  \
# 100         82       Wales  Real Madrid  ...  72+3  69+3  69+3  69+3  72+3
# 106         75    Colombia  Real Madrid  ...  67+3  67+3  67+3  67+3  67+3
# 4           74     Belgium  Real Madrid  ...  66+3  63+3  63+3  63+3  66+3
#
#        lb   lcb    cb   rcb    rb
# 100  70+3  66+3  66+3  66+3  70+3
# ...

# %%
realmadrid['nationality'].value_counts()
# Out:
# nationality
# Spain                 13
# Brazil                 6
# France                 3
# Belgium                2
# Croatia                1
# Germany                1
# Costa Rica             1
# Wales                  1
# Colombia               1
# Serbia                 1
# Dominican Republic     1
# Uruguay                1
# Japan                  1
# Name: count, dtype: int64
